# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv("dengue_features_train3.csv", index_col = 0)
df_labels = pd.read_csv("dengue_labels_train.csv",index_col = 0)

df['total_cases'] = df_labels['total_cases']

# %%
df
# Out:
#       year  weekofyear week_start_date  precipitation_amt_mm  \
# city
# sj    1990          18       4/30/1990                 12.42
# sj    1990          19        5/7/1990                 22.82
# sj    1990          20       5/14/1990                 34.54
# sj    1990          21       5/21/1990                 15.36
# sj    1990          22       5/28/1990                  7.52
# ...    ...         ...             ...                   ...
# iq    2010          21       5/28/2010                 55.30
# iq    2010          22        6/4/2010                 86.47
# iq    2010          23       6/11/2010                 58.94
# iq    2010          24       6/18/2010                 59.67
# iq    2010          25       6/25/2010                 63.22
#
#       reanalysis_air_temp_k  reanalysis_avg_temp_k  \
# city
# sj               297.572857             297.742857
# sj               298.211429             298.442857
# sj               298.781429             298.878571
# ...

# %%
df.head()
# Out:
#       year  weekofyear week_start_date  precipitation_amt_mm  \
# city
# sj    1990          18       4/30/1990                 12.42
# sj    1990          19        5/7/1990                 22.82
# sj    1990          20       5/14/1990                 34.54
# sj    1990          21       5/21/1990                 15.36
# sj    1990          22       5/28/1990                  7.52
#
#       reanalysis_air_temp_k  reanalysis_avg_temp_k  \
# city
# sj               297.572857             297.742857
# sj               298.211429             298.442857
# sj               298.781429             298.878571
# sj               298.987143             299.228571
# sj               299.518571             299.664286
#
#       reanalysis_dew_point_temp_k  reanalysis_max_air_temp_k  \
# city
# sj                     292.414286                      299.8
# sj                     293.951429                      300.9
# sj                     295.434286                      300.5
# ...

# %%
df.tail()
# Out:
#       year  weekofyear week_start_date  precipitation_amt_mm  \
# city
# iq    2010          21       5/28/2010                 55.30
# iq    2010          22        6/4/2010                 86.47
# iq    2010          23       6/11/2010                 58.94
# iq    2010          24       6/18/2010                 59.67
# iq    2010          25       6/25/2010                 63.22
#
#       reanalysis_air_temp_k  reanalysis_avg_temp_k  \
# city
# iq               299.334286             300.771429
# iq               298.330000             299.392857
# iq               296.598571             297.592857
# iq               296.345714             297.521429
# iq               298.097143             299.835714
#
#       reanalysis_dew_point_temp_k  reanalysis_max_air_temp_k  \
# city
# iq                     296.825714                      309.7
# iq                     296.452857                      308.5
# iq                     295.501429                      305.5
# ...

# %%
df_sj = df.loc['sj']
df_iq = df.loc['iq']

# %%
X_sj = df_sj[['year','weekofyear','precipitation_amt_mm','reanalysis_air_temp_k','reanalysis_avg_temp_k','reanalysis_dew_point_temp_k','reanalysis_max_air_temp_k','reanalysis_min_air_temp_k','reanalysis_precip_amt_kg_per_m2','reanalysis_relative_humidity_percent','reanalysis_sat_precip_amt_mm','reanalysis_specific_humidity_g_per_kg','reanalysis_tdtr_k']]
X_iq = df_iq[['year','weekofyear','precipitation_amt_mm','reanalysis_air_temp_k','reanalysis_avg_temp_k','reanalysis_dew_point_temp_k','reanalysis_max_air_temp_k','reanalysis_min_air_temp_k','reanalysis_precip_amt_kg_per_m2','reanalysis_relative_humidity_percent','reanalysis_sat_precip_amt_mm','reanalysis_specific_humidity_g_per_kg','reanalysis_tdtr_k']]

# %%
y_sj = df_sj[['total_cases']]
y_iq = df_iq[['total_cases']]

# %%
X_sj.describe()
# Out:
#               year  weekofyear  precipitation_amt_mm  reanalysis_air_temp_k  \
# count   936.000000  936.000000            927.000000             930.000000
# mean   1998.826923   26.503205             35.470809             299.163653
# std       5.212076   15.021909             44.606137               1.236429
# min    1990.000000    1.000000              0.000000             295.938571
# 25%    1994.000000   13.750000              0.000000             298.195000
# 50%    1999.000000   26.500000             20.800000             299.254286
# 75%    2003.000000   39.250000             52.180000             300.132857
# max    2008.000000   53.000000            390.600000             302.200000
#
#        reanalysis_avg_temp_k  reanalysis_dew_point_temp_k  \
# count             930.000000                   930.000000
# mean              299.276920                   295.109519
# std                 1.218637                     1.569943
# ...

# %%
X_sj.corr()
# Out:
#                                            year  weekofyear  \
# year                                   1.000000   -0.073143
# weekofyear                            -0.073143    1.000000
# precipitation_amt_mm                   0.031612    0.231961
# reanalysis_air_temp_k                  0.185813    0.575381
# reanalysis_avg_temp_k                  0.189696    0.561001
# reanalysis_dew_point_temp_k            0.015428    0.578072
# reanalysis_max_air_temp_k              0.177772    0.519083
# reanalysis_min_air_temp_k              0.105355    0.574494
# reanalysis_precip_amt_kg_per_m2       -0.132494    0.253975
# reanalysis_relative_humidity_percent  -0.286206    0.306771
# reanalysis_sat_precip_amt_mm           0.031612    0.231961
# reanalysis_specific_humidity_g_per_kg  0.018129    0.585224
# reanalysis_tdtr_k                      0.325336   -0.099084
#
#                                        precipitation_amt_mm  \
# year                                               0.031612
# ...

# %%
X_iq.corr()
# Out:
#                                            year  weekofyear  \
# year                                   1.000000   -0.136842
# weekofyear                            -0.136842    1.000000
# precipitation_amt_mm                   0.085287   -0.116018
# reanalysis_air_temp_k                  0.023359    0.293305
# reanalysis_avg_temp_k                  0.006082    0.305944
# reanalysis_dew_point_temp_k            0.318394   -0.100417
# reanalysis_max_air_temp_k             -0.156489    0.411810
# reanalysis_min_air_temp_k              0.215859   -0.029626
# reanalysis_precip_amt_kg_per_m2        0.164225   -0.148021
# reanalysis_relative_humidity_percent   0.256166   -0.287737
# reanalysis_sat_precip_amt_mm           0.085287   -0.116018
# reanalysis_specific_humidity_g_per_kg  0.321922   -0.090302
# reanalysis_tdtr_k                     -0.235968    0.353218
#
#                                        precipitation_amt_mm  \
# year                                               0.085287
# ...

# %%
X_sj.isnull().sum()
# Out:
# year                                     0
# weekofyear                               0
# precipitation_amt_mm                     9
# reanalysis_air_temp_k                    6
# reanalysis_avg_temp_k                    6
# reanalysis_dew_point_temp_k              6
# reanalysis_max_air_temp_k                6
# reanalysis_min_air_temp_k                6
# reanalysis_precip_amt_kg_per_m2          6
# reanalysis_relative_humidity_percent     6
# reanalysis_sat_precip_amt_mm             9
# reanalysis_specific_humidity_g_per_kg    6
# reanalysis_tdtr_k                        6
# dtype: int64

# %%
X_iq.isnull().sum()
# Out:
# year                                     0
# weekofyear                               0
# precipitation_amt_mm                     4
# reanalysis_air_temp_k                    4
# reanalysis_avg_temp_k                    4
# reanalysis_dew_point_temp_k              4
# reanalysis_max_air_temp_k                4
# reanalysis_min_air_temp_k                4
# reanalysis_precip_amt_kg_per_m2          4
# reanalysis_relative_humidity_percent     4
# reanalysis_sat_precip_amt_mm             4
# reanalysis_specific_humidity_g_per_kg    4
# reanalysis_tdtr_k                        4
# dtype: int64

# %%
X_sj.shape ,X_iq.shape
# Out:
# ((936, 13), (520, 13))

# %%
X_sj.dtypes ,X_iq.dtypes
# Out:
# (year                                       int64
#  weekofyear                                 int64
#  precipitation_amt_mm                     float64
#  reanalysis_air_temp_k                    float64
#  reanalysis_avg_temp_k                    float64
#  reanalysis_dew_point_temp_k              float64
#  reanalysis_max_air_temp_k                float64
#  reanalysis_min_air_temp_k                float64
#  reanalysis_precip_amt_kg_per_m2          float64
#  reanalysis_relative_humidity_percent     float64
#  reanalysis_sat_precip_amt_mm             float64
#  reanalysis_specific_humidity_g_per_kg    float64
#  reanalysis_tdtr_k                        float64
#  dtype: object,
#  year                                       int64
#  weekofyear                                 int64
#  precipitation_amt_mm                     float64
#  reanalysis_air_temp_k                    float64
#  reanalysis_avg_temp_k                    float64
# ...

# %%
#from sklearn.experimental import enable_iterative_imputer
##from sklearn.impute import IterativeImputer
#impute_it = IterativeImputer()
#impute_it.fit_transform(X_sj)

# %%
#X = impute_it.fit_transform(X_sj)
#np.isnan(X).sum()

# %%
X_sj = X_sj.interpolate(method="linear")
X_sj
# Out:
#       year  weekofyear  precipitation_amt_mm  reanalysis_air_temp_k  \
# city
# sj    1990          18                 12.42             297.572857
# sj    1990          19                 22.82             298.211429
# sj    1990          20                 34.54             298.781429
# sj    1990          21                 15.36             298.987143
# sj    1990          22                  7.52             299.518571
# ...    ...         ...                   ...                    ...
# sj    2008          13                 27.19             296.958571
# sj    2008          14                  3.82             298.081429
# sj    2008          15                 16.96             297.460000
# sj    2008          16                  0.00             297.630000
# sj    2008          17                  0.00             298.672857
#
#       reanalysis_avg_temp_k  reanalysis_dew_point_temp_k  \
# city
# sj               297.742857                   292.414286
# ...

# %%
X_sj.isnull().sum()
# Out:
# year                                     0
# weekofyear                               0
# precipitation_amt_mm                     0
# reanalysis_air_temp_k                    0
# reanalysis_avg_temp_k                    0
# reanalysis_dew_point_temp_k              0
# reanalysis_max_air_temp_k                0
# reanalysis_min_air_temp_k                0
# reanalysis_precip_amt_kg_per_m2          0
# reanalysis_relative_humidity_percent     0
# reanalysis_sat_precip_amt_mm             0
# reanalysis_specific_humidity_g_per_kg    0
# reanalysis_tdtr_k                        0
# dtype: int64

# %%
X_iq = X_iq.interpolate(method="linear")
X_iq.isnull().sum()
# Out:
# year                                     0
# weekofyear                               0
# precipitation_amt_mm                     0
# reanalysis_air_temp_k                    0
# reanalysis_avg_temp_k                    0
# reanalysis_dew_point_temp_k              0
# reanalysis_max_air_temp_k                0
# reanalysis_min_air_temp_k                0
# reanalysis_precip_amt_kg_per_m2          0
# reanalysis_relative_humidity_percent     0
# reanalysis_sat_precip_amt_mm             0
# reanalysis_specific_humidity_g_per_kg    0
# reanalysis_tdtr_k                        0
# dtype: int64

# %%
X_sj.shape ,X_iq.shape
# Out:
# ((936, 13), (520, 13))

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error

# %%
from sklearn.ensemble import GradientBoostingRegressor

# %%
train_X, test_X, train_y, test_y = train_test_split(X_sj, y_sj,
                      test_size = 0.3, random_state = 50)

# %%
params = {
    "n_estimators": 200,
    "max_depth": 10,
    "min_samples_split":5,
    "learning_rate": 0.02,
    "criterion": "mse"
}

# %%
reg = GradientBoostingRegressor(**params)
reg.fit(train_X, train_y)
# Out:
# E:\Anaconda\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# GradientBoostingRegressor(criterion='mse', learning_rate=0.02, max_depth=10,
#                           min_samples_split=5, n_estimators=200)

# %%
y_pred = reg.predict(train_X)

# %%
 mean_absolute_error(train_y, y_pred)
# Out:
# 0.2422634871457606

# %%
y_pred = reg.predict(test_X)
mean_absolute_error(test_y, y_pred)
# Out:
# 5.217474507779174

# %%
#spliting the data for iq city
train_X, test_X, train_y, test_y = train_test_split(X_iq, y_iq,
                      test_size = 0.3, random_state = 50)

# %%
params = {
    "n_estimators": 100,
    "max_depth": 20,
    "min_samples_split":5,
    "learning_rate": 0.02,
    "criterion": "mse"
}

# %%
reg = GradientBoostingRegressor(**params)
reg.fit(train_X, train_y)
# Out:
# E:\Anaconda\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# GradientBoostingRegressor(criterion='mse', learning_rate=0.02, max_depth=20,
#                           min_samples_split=5)

# %%
y_pred = reg.predict(train_X)

# %%
mean_absolute_error(train_y, y_pred)
# Out:
# 0.8945597616243847

# %%
y_pred = reg.predict(test_X)
mean_absolute_error(test_y, y_pred)
# Out:
# 5.361879636912675

# %% [markdown]
# 1.Analysis Dataset By using the EDA process(Exploratory Data Analysis)
# 2.Filling the missing values using linear interpolation
# 3.Divide Dataset into Sq and iq
# 4. On the basis of the selected feature given by the madam make Used model Gradient boosting method to build the model
# 5.San juan mean absoute error
# For train set = 0.2422634871457606
# For test set  = 5.217474507779174
# 6.iquitos mean absoute error
# For train set = 0.8945597616243847
# For test set = 5.361879636912675
# 7. Used random forset to find the important features
# 8.selected feature are =
# 8.On the basis of the selected feature given by the madam make Used model Gradient boosting method to build the model

# %%
reg = GradientBoostingRegressor(**params)
reg.fit(X_sj, y_sj)
# Out:
# E:\Anaconda\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# GradientBoostingRegressor(criterion='mse', learning_rate=0.02, max_depth=10,
#                           min_samples_split=5, n_estimators=200)

# %%
mean_absolute_error(reg.predict(X_sj), y_sj)
# Out:
# 1.045310821713573

# %%
plt.figure(figsize = (20, 5))
plt.plot(y_sj.values.reshape(-1, 1))
plt.plot(reg.predict(X_sj))

# %%
reg = GradientBoostingRegressor(**params)
reg.fit(X_iq, y_iq)
# Out:
# E:\Anaconda\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# GradientBoostingRegressor(criterion='mse', learning_rate=0.02, max_depth=10,
#                           min_samples_split=5, n_estimators=200)

# %%
mean_absolute_error(reg.predict(X_iq), y_iq)
# Out:
# 0.3123869814793791

# %%
plt.figure(figsize = (20, 5))
plt.plot(y_iq.values.reshape(-1, 1))
plt.plot(reg.predict(X_iq))
